# %%
# 展示节点之间相互关系  # e.g. 社交网络交互、贸易与经济流向

# %%
# 1.节点链接图(Node-Link Diagram)

# %%
# 2.矩阵热图 (Adjacency Matrix)

# %%
# 3. 弦图 (Chord Diagram)

# %%
# 4. 桑基图 (Sankey Diagram)

# %%
# 5. 弧线图 (Arc Diagram)
