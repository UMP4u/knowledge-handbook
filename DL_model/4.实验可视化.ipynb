# %%
# 模型稳健性
# 训练高级技巧（效率与精度）
# 实验可视化（拒绝黑盒）

# %%
# 实验可视化
# pip install tensorboard

from torch.utils.tensorboard import SummaryWriter # 导入记录员
import torch

# 1. 初始化记录员，日志存放在 'runs/income_experiment' 文件夹
writer = SummaryWriter('runs/income_experiment')

# ... 之前的模型定义、优化器等 ...

for epoch in range(epochs):
    model.train()
    train_loss = 0.0
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        
        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
    
    # 【关键步】每个 Epoch 结束，记录平均 Loss 到 TensorBoard
    avg_train_loss = train_loss / len(train_loader)
    writer.add_scalar('Loss/Train', avg_train_loss, epoch)
    
    # 模拟一个验证集 Loss（假设你已经写了验证逻辑）
    # writer.add_scalar('Loss/Validation', val_loss, epoch)

    print(f"Epoch {epoch} 完成，日志已写入")

# 训练结束，关闭记录员
writer.close()
