# %%
# 导出requirements.txt
pip install pipreqs
pipreqs . --encoding=utf-8 --force

# 导出pyproject.toml
pip install poetry
poetry init
cat requirements.txt | ForEach-Object { poetry add $_ }

# 使用txt安装环境（已经在一个环境中）
pip install -r requirements.txt

# %%
pip install pipreqs
pipreqs . --encoding=utf-8 --force
pip install -r requirements.txt
