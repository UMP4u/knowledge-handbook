# %%
# 1.1.2 Workspace

# --- 1. Workspace (工作空间) 管理 ---

# 查看当前工作空间中的所有对象（变量、函数等）
ls()
objects()

# 删除特定的对象 (例如删除变量 x)
# rm(x) 

# 【常用】删除工作空间中的所有对象 (清空内存)
rm(list = ls())


# --- 2. Working Directory (工作目录) 管理 ---

# 查看当前 R 正在使用的文件夹路径
getwd()

# 设置/更改工作目录
# 注意：在 Windows 中路径需使用正斜杠 "/" 或双反斜杠 "\\"
# setwd("C:/Users/YourName/Documents/Project_R")

# --- 保存与加载数据 ---

# 1. 保存选定的对象
# save(object1, object2, file = "selection.RData")

# 2. 保存整个工作空间的所有对象
save.image("all_work.RData")

# 3. 加载之前保存的数据
load("all_work.RData")

# 注意：.RData 是 R 专用的二进制格式，存储效率高但无法用记事本直接打开

# %%
# 1.1.3 Script Files

# read R Code from a File
source ("file.R") 


# 1.1.4 R packages
Install package: install.packages("ggplot2").
Load package: library(ggplot2).

# %%
# 1.2.1 Read Data From Files

read.table(file, header = FALSE, sep = " ")
# FALSE（默认）：表示文件里全是数据，没有标题行。如果选了这个，R 会自动把列命名为 V1, V2, V3.
#  CSV 文件，这里就是逗号 ","分隔数据
# dec = "."：默认认为小数点是一个点（如 3.14），欧洲为","(3,14)

# 处理标准 CSV： 直接用 read.csv("文件名.csv")
# 处理 .txt 格式的表格： 用 read.delim("文件名.txt") Delimit er（分隔符）

quote = "\""        # "北京市, 海淀区, 某大厦",使得引号里面的内容是一个整体，不管里面有没有逗号
fill = TRUE         #自动补齐“缺课”的数据
comment.char = "#"  #无视该注释 

e.g.
# 这是一个实验数据
# 采集日期：2023-10-01
ID, Value
1, 100

# %%
write.csv(你的变量名, "结果.csv", row.names = FALSE)
# 默认会把 R 里的行索引（1, 2, 3...）也存进文件； col.names = TRUE

# %%
  d、p、q、r + 分布
density,probability,quantile,random

# %%
ifelse(test, yes, no)
ifelse(scores >= 60, "及格", "不及格")

# %%
%*%：矩阵乘法

# 1. 定义
"%add_square%" <- function(x, y) {
  return((x + y)^2)
}
# 2. 使用
2 %add_square% 3  # 结果是 (2+3)^2 = 25

# %%
R Markdown：你在同一个文件里写文字和代码。当你点击“渲染”时，R 会自动运行代码，
把生成的图表直接插在文字中间

修改了数据，只需重新运行一遍即可，不必像word全部重新粘贴

代码块 ```r     
    ```

# %%
 R Shiny App
 ui server shinyapp

 ui <- fluidPage(
)   #流式页面

# Define server logic
server <- function(input, output) {
}
shinyApp(ui = ui, server = server)
