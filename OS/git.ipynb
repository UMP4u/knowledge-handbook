# %%
.gitignore语法

1.忽略特定后缀：使用星号 *
*.pth：忽略所有 PyTorch 权重文件
*.log：忽略所有日志文件

2.忽略整个文件夹：文件夹名后加斜杠 /
data/：忽略根目录下 data 文件夹及其内部所有内容
**/temp/：忽略任何子目录下的 temp 文件夹

3.例外规则：使用感叹号 !
*.jpg
# !cat.jpg：忽略所有 jpg 图片，但除了 cat.jpg

# %%
git reset
#只是 git add 了，还没有 git commit

#已经 git commit 了，但 git push 失败
# 撤销最后一次提交，但保留你写的代码改动
git reset --soft HEAD~1

# 查看暂存区文件状态
git status
