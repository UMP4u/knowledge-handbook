# %%
import torch
import torch.nn as nn

x = torch.randn(4, 4)
y = x.view(16) #view等同于numpy的reshape
z = x.view(-1, 8)  #  size -1 从其他维度推断

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
data = torch.rand(3, 3)
data = data.to(device)
print(f"数据当前所在设备: {data.device}")
